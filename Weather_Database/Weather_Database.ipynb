# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | adrar
# Processing Record 2 of Set 1 | avarua
# Processing Record 3 of Set 1 | umm lajj
# Processing Record 4 of Set 1 | puerto leguizamo
# Processing Record 5 of Set 1 | barrow
# Processing Record 6 of Set 1 | kyra
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | likasi
# Processing Record 10 of Set 1 | atuona
# Processing Record 11 of Set 1 | talara
# Processing Record 12 of Set 1 | pipri
# Processing Record 13 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | polunochnoye
# Processing Record 20 of Set 1 | hithadhoo
# Processing Record 21 of Set 1 | san quintin
# Processing Record 22 of Set 1 | batagay
# Processing Record 23 of Set 1 | gurskoye
# City not found. Skipping...
# Processing Record 24 of Set 1 | totness
# Processing Record 25 of Set 1 | margate
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | asau
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | necochea
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | dhekiajuli
# Processing Record 32 of Set 1 | kysyl-syr
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | wentzville
# Processing Record 37 of Set 1 | serebryansk
# Processing Record 38 of Set 1 | oksfjord
# Processing Record 39 of Set 1 | montrose
# Processing Record 40 of Set 1 | qasigiannguit
# Processing Record 41 of Set 1 | mezen
# Processing Record 42 of Set 1 | half moon bay
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | zhigansk
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | narsaq
# Processing Record 49 of Set 1 | liepaja
# Processing Record 50 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | constitucion
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | port alfred
# Processing Record 5 of Set 2 | beira
# Processing Record 6 of Set 2 | svetlaya
# Processing Record 7 of Set 2 | waingapu
# Processing Record 8 of Set 2 | shingu
# Processing Record 9 of Set 2 | ponta do sol
# Processing Record 10 of Set 2 | nome
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | mount gambier
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | northam
# Processing Record 16 of Set 2 | tanout
# Processing Record 17 of Set 2 | hualmay
# Processing Record 18 of Set 2 | nanortalik
# Processing Record 19 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 2 | cape town
# Processing Record 21 of Set 2 | fort smith
# Processing Record 22 of Set 2 | trofors
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | ushuaia
# Processing Record 25 of Set 2 | sao raimundo das mangabeiras
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | iqaluit
# Processing Record 28 of Set 2 | salalah
# Processing Record 29 of Set 2 | gladstone
# Processing Record 30 of Set 2 | sisimiut
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | upata
# Processing Record 33 of Set 2 | portland
# Processing Record 34 of Set 2 | yeppoon
# Processing Record 35 of Set 2 | fortuna
# Processing Record 36 of Set 2 | verkhoyansk
# Processing Record 37 of Set 2 | north bend
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | pundaguitan
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | camacha
# Processing Record 42 of Set 2 | ngaoundere
# Processing Record 43 of Set 2 | kahului
# Processing Record 44 of Set 2 | lasa
# Processing Record 45 of Set 2 | aranos
# Processing Record 46 of Set 2 | jumla
# Processing Record 47 of Set 2 | dunedin
# Processing Record 48 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | dikson
# Processing Record 2 of Set 3 | brae
# Processing Record 3 of Set 3 | sabalgarh
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | pueblo nuevo
# Processing Record 6 of Set 3 | acarau
# Processing Record 7 of Set 3 | port blair
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | chuy
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | moerai
# Processing Record 12 of Set 3 | banjar
# Processing Record 13 of Set 3 | kruisfontein
# Processing Record 14 of Set 3 | hermanus
# Processing Record 15 of Set 3 | san rafael del sur
# Processing Record 16 of Set 3 | teneguiban
# City not found. Skipping...
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | sembe
# Processing Record 19 of Set 3 | cabo san lucas
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | teya
# Processing Record 22 of Set 3 | mpika
# Processing Record 23 of Set 3 | esna
# Processing Record 24 of Set 3 | qaanaaq
# Processing Record 25 of Set 3 | moba
# Processing Record 26 of Set 3 | nishihara
# Processing Record 27 of Set 3 | mashhad
# Processing Record 28 of Set 3 | tessalit
# Processing Record 29 of Set 3 | noumea
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | turukhansk
# Processing Record 32 of Set 3 | pisco
# Processing Record 33 of Set 3 | ilulissat
# Processing Record 34 of Set 3 | sibolga
# Processing Record 35 of Set 3 | sagua la grande
# Processing Record 36 of Set 3 | aksu
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | abha
# Processing Record 40 of Set 3 | ferkessedougou
# Processing Record 41 of Set 3 | vrable
# Processing Record 42 of Set 3 | samos
# Processing Record 43 of Set 3 | fort nelson
# Processing Record 44 of Set 3 | port hardy
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | ocara
# Processing Record 47 of Set 3 | souillac
# Processing Record 48 of Set 3 | snezhnogorsk
# Processing Record 49 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | bamako
# Processing Record 3 of Set 4 | mayor pablo lagerenza
# Processing Record 4 of Set 4 | airai
# Processing Record 5 of Set 4 | bolu
# Processing Record 6 of Set 4 | victoria
# Processing Record 7 of Set 4 | bumba
# Processing Record 8 of Set 4 | ucluelet
# Processing Record 9 of Set 4 | hamilton
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | andenes
# Processing Record 12 of Set 4 | kifri
# Processing Record 13 of Set 4 | bengkulu
# Processing Record 14 of Set 4 | vilyuysk
# Processing Record 15 of Set 4 | faya
# Processing Record 16 of Set 4 | tuktoyaktuk
# Processing Record 17 of Set 4 | deputatskiy
# Processing Record 18 of Set 4 | rocha
# Processing Record 19 of Set 4 | mayumba
# Processing Record 20 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 4 | laela
# Processing Record 22 of Set 4 | belyy yar
# Processing Record 23 of Set 4 | pavilosta
# Processing Record 24 of Set 4 | la rioja
# Processing Record 25 of Set 4 | hasaki
# Processing Record 26 of Set 4 | bethel
# Processing Record 27 of Set 4 | bastia
# Processing Record 28 of Set 4 | port elizabeth
# Processing Record 29 of Set 4 | kamenka
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | nizhnevartovsk
# Processing Record 32 of Set 4 | xadani
# City not found. Skipping...
# Processing Record 33 of Set 4 | chokurdakh
# Processing Record 34 of Set 4 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 4 | staryy nadym
# Processing Record 36 of Set 4 | beloha
# Processing Record 37 of Set 4 | wattegama
# Processing Record 38 of Set 4 | hokitika
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | castro
# Processing Record 41 of Set 4 | djibo
# Processing Record 42 of Set 4 | ullapool
# Processing Record 43 of Set 4 | kontagora
# Processing Record 44 of Set 4 | srednekolymsk
# Processing Record 45 of Set 4 | barinitas
# Processing Record 46 of Set 4 | tuatapere
# Processing Record 47 of Set 4 | moyale
# Processing Record 48 of Set 4 | eenhana
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | matara
# Processing Record 1 of Set 5 | graaff-reinet
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | mecca
# Processing Record 4 of Set 5 | ixtapa
# Processing Record 5 of Set 5 | arcachon
# Processing Record 6 of Set 5 | christchurch
# Processing Record 7 of Set 5 | santiago de las vegas
# Processing Record 8 of Set 5 | gizo
# Processing Record 9 of Set 5 | sorland
# Processing Record 10 of Set 5 | qaqortoq
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | tocopilla
# Processing Record 13 of Set 5 | nelson bay
# Processing Record 14 of Set 5 | kharitonovo
# Processing Record 15 of Set 5 | okha
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | onega
# Processing Record 18 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 5 | lahaina
# Processing Record 20 of Set 5 | price
# Processing Record 21 of Set 5 | gamba
# Processing Record 22 of Set 5 | kendari
# Processing Record 23 of Set 5 | faanui
# Processing Record 24 of Set 5 | manoharpur
# Processing Record 25 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 26 of Set 5 | bilibino
# Processing Record 27 of Set 5 | bilecik
# Processing Record 28 of Set 5 | la curva
# Processing Record 29 of Set 5 | sembakung
# Processing Record 30 of Set 5 | katobu
# Processing Record 31 of Set 5 | klaksvik
# Processing Record 32 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 5 | tukrah
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | mahebourg
# Processing Record 36 of Set 5 | valparaiso
# Processing Record 37 of Set 5 | nanakuli
# Processing Record 38 of Set 5 | egvekinot
# Processing Record 39 of Set 5 | tucupita
# Processing Record 40 of Set 5 | koumac
# Processing Record 41 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 5 | kuching
# Processing Record 43 of Set 5 | huhi
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | basay
# Processing Record 46 of Set 5 | tel aviv-yafo
# Processing Record 47 of Set 5 | chitaga
# Processing Record 48 of Set 5 | kabalo
# Processing Record 49 of Set 5 | longyearbyen
# Processing Record 50 of Set 5 | imbituba
# Processing Record 1 of Set 6 | kem
# Processing Record 2 of Set 6 | anamur
# Processing Record 3 of Set 6 | kavaratti
# Processing Record 4 of Set 6 | comodoro rivadavia
# Processing Record 5 of Set 6 | caravelas
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | eydhafushi
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | sambava
# Processing Record 10 of Set 6 | mahajanga
# Processing Record 11 of Set 6 | weligama
# Processing Record 12 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 6 | kodiak
# Processing Record 14 of Set 6 | brandon
# Processing Record 15 of Set 6 | ola
# Processing Record 16 of Set 6 | lagoa
# Processing Record 17 of Set 6 | havoysund
# Processing Record 18 of Set 6 | asyut
# Processing Record 19 of Set 6 | husavik
# Processing Record 20 of Set 6 | orlik
# Processing Record 21 of Set 6 | takoradi
# Processing Record 22 of Set 6 | naze
# Processing Record 23 of Set 6 | tautira
# Processing Record 24 of Set 6 | quatre cocos
# Processing Record 25 of Set 6 | pafos
# Processing Record 26 of Set 6 | sao filipe
# Processing Record 27 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 6 | hofn
# Processing Record 29 of Set 6 | suntar
# Processing Record 30 of Set 6 | suez
# Processing Record 31 of Set 6 | prestea
# Processing Record 32 of Set 6 | saskylakh
# Processing Record 33 of Set 6 | chunhuhub
# Processing Record 34 of Set 6 | ndola
# Processing Record 35 of Set 6 | sao joao da barra
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | pevek
# Processing Record 38 of Set 6 | buin
# Processing Record 39 of Set 6 | paka
# Processing Record 40 of Set 6 | lazaro cardenas
# Processing Record 41 of Set 6 | havelock
# Processing Record 42 of Set 6 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 6 | ranong
# Processing Record 44 of Set 6 | kapit
# Processing Record 45 of Set 6 | itaituba
# Processing Record 46 of Set 6 | ekhabi
# Processing Record 47 of Set 6 | nampula
# Processing Record 48 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 6 | lakes entrance
# Processing Record 50 of Set 6 | ozubulu
# Processing Record 1 of Set 7 | potiskum
# Processing Record 2 of Set 7 | fengzhen
# Processing Record 3 of Set 7 | zinapecuaro
# Processing Record 4 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 7 | sawtell
# Processing Record 6 of Set 7 | lamar
# Processing Record 7 of Set 7 | khonsa
# Processing Record 8 of Set 7 | kloulklubed
# Processing Record 9 of Set 7 | piranshahr
# Processing Record 10 of Set 7 | domoni
# Processing Record 11 of Set 7 | henties bay
# Processing Record 12 of Set 7 | green river
# Processing Record 13 of Set 7 | sola
# Processing Record 14 of Set 7 | bahia blanca
# Processing Record 15 of Set 7 | olafsvik
# Processing Record 16 of Set 7 | pasighat
# Processing Record 17 of Set 7 | cidreira
# Processing Record 18 of Set 7 | ukiah
# Processing Record 19 of Set 7 | kaya
# Processing Record 20 of Set 7 | bandarbeyla
# Processing Record 21 of Set 7 | baripada
# Processing Record 22 of Set 7 | yar-sale
# Processing Record 23 of Set 7 | bubaque
# Processing Record 24 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 7 | bose
# Processing Record 26 of Set 7 | tiarei
# Processing Record 27 of Set 7 | opunake
# Processing Record 28 of Set 7 | dubbo
# Processing Record 29 of Set 7 | ripky
# Processing Record 30 of Set 7 | wadi maliz
# Processing Record 31 of Set 7 | beringovskiy
# Processing Record 32 of Set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 33 of Set 7 | college
# Processing Record 34 of Set 7 | san pedro
# Processing Record 35 of Set 7 | surgut
# Processing Record 36 of Set 7 | kang
# Processing Record 37 of Set 7 | shitanjing
# Processing Record 38 of Set 7 | paamiut
# Processing Record 39 of Set 7 | saldanha
# Processing Record 40 of Set 7 | katsuura
# Processing Record 41 of Set 7 | cairns
# Processing Record 42 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 7 | conceicao do araguaia
# Processing Record 44 of Set 7 | yulara
# Processing Record 45 of Set 7 | wheeling
# Processing Record 46 of Set 7 | bam
# Processing Record 47 of Set 7 | bambous virieux
# Processing Record 48 of Set 7 | bilma
# Processing Record 49 of Set 7 | wajima
# Processing Record 50 of Set 7 | bacolod
# Processing Record 1 of Set 8 | ardesen
# Processing Record 2 of Set 8 | walvis bay
# Processing Record 3 of Set 8 | vila
# Processing Record 4 of Set 8 | sebu
# Processing Record 5 of Set 8 | montgomery
# Processing Record 6 of Set 8 | te anau
# Processing Record 7 of Set 8 | birao
# Processing Record 8 of Set 8 | saint george
# Processing Record 9 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 8 | boguchany
# Processing Record 12 of Set 8 | aklavik
# Processing Record 13 of Set 8 | sao felix do xingu
# Processing Record 14 of Set 8 | berbera
# Processing Record 15 of Set 8 | san patricio
# Processing Record 16 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 17 of Set 8 | weihe
# Processing Record 18 of Set 8 | ashland
# Processing Record 19 of Set 8 | lufilufi
# Processing Record 20 of Set 8 | cockburn town
# Processing Record 21 of Set 8 | lorengau
# Processing Record 22 of Set 8 | general roca
# Processing Record 23 of Set 8 | rio bueno
# Processing Record 24 of Set 8 | vytegra
# Processing Record 25 of Set 8 | concepcion del uruguay
# Processing Record 26 of Set 8 | tabuk
# Processing Record 27 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 8 | prince albert
# Processing Record 29 of Set 8 | carupano
# Processing Record 30 of Set 8 | grand baie
# Processing Record 31 of Set 8 | rumboci
# Processing Record 32 of Set 8 | duldurga
# Processing Record 33 of Set 8 | bangkal
# Processing Record 34 of Set 8 | komsomolskiy
# Processing Record 35 of Set 8 | pangnirtung
# Processing Record 36 of Set 8 | tromso
# Processing Record 37 of Set 8 | volodarskiy
# Processing Record 38 of Set 8 | san policarpo
# Processing Record 39 of Set 8 | guerrero negro
# Processing Record 40 of Set 8 | isiro
# Processing Record 41 of Set 8 | stokmarknes
# Processing Record 42 of Set 8 | omboue
# Processing Record 43 of Set 8 | fasa
# Processing Record 44 of Set 8 | sechura
# Processing Record 45 of Set 8 | kurumkan
# Processing Record 46 of Set 8 | ponta delgada
# Processing Record 47 of Set 8 | esperance
# Processing Record 48 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 49 of Set 8 | lima
# Processing Record 50 of Set 8 | santarem
# Processing Record 1 of Set 9 | aqtobe
# Processing Record 2 of Set 9 | jertih
# Processing Record 3 of Set 9 | bell ville
# Processing Record 4 of Set 9 | ketchikan
# Processing Record 5 of Set 9 | wiwili
# Processing Record 6 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 7 of Set 9 | mahina
# Processing Record 8 of Set 9 | umm durman
# City not found. Skipping...
# Processing Record 9 of Set 9 | huarmey
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | sohbatpur
# Processing Record 12 of Set 9 | santa maria
# Processing Record 13 of Set 9 | buchanan
# Processing Record 14 of Set 9 | canavieiras
# Processing Record 15 of Set 9 | matadi
# Processing Record 16 of Set 9 | nurota
# Processing Record 17 of Set 9 | camana
# Processing Record 18 of Set 9 | coihaique
# Processing Record 19 of Set 9 | aktyubinskiy
# Processing Record 20 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 9 | trelew
# Processing Record 22 of Set 9 | byron bay
# Processing Record 23 of Set 9 | muisne
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | kangaatsiaq
# Processing Record 26 of Set 9 | ritchie
# Processing Record 27 of Set 9 | akyab
# Processing Record 28 of Set 9 | marawi
# Processing Record 29 of Set 9 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 9 | gaillac
# Processing Record 32 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 9 | zhangjiakou
# Processing Record 34 of Set 9 | dwarka
# Processing Record 35 of Set 9 | hondo
# Processing Record 36 of Set 9 | luganville
# Processing Record 37 of Set 9 | cabedelo
# Processing Record 38 of Set 9 | poum
# Processing Record 39 of Set 9 | assiniboia
# Processing Record 40 of Set 9 | vinh long
# Processing Record 41 of Set 9 | novyy urengoy
# Processing Record 42 of Set 9 | baker city
# Processing Record 43 of Set 9 | tepusteca
# Processing Record 44 of Set 9 | pemba
# Processing Record 45 of Set 9 | pacific grove
# Processing Record 46 of Set 9 | ouadda
# Processing Record 47 of Set 9 | bridgewater
# Processing Record 48 of Set 9 | san vicente
# Processing Record 49 of Set 9 | aksarka
# Processing Record 50 of Set 9 | jiayuguan
# Processing Record 1 of Set 10 | nantucket
# Processing Record 2 of Set 10 | veraval
# Processing Record 3 of Set 10 | presidencia roque saenz pena
# Processing Record 4 of Set 10 | barra patuca
# Processing Record 5 of Set 10 | port lincoln
# Processing Record 6 of Set 10 | fangshan
# Processing Record 7 of Set 10 | sitka
# Processing Record 8 of Set 10 | boddam
# Processing Record 9 of Set 10 | sussex
# Processing Record 10 of Set 10 | ulaanbaatar
# Processing Record 11 of Set 10 | tahoua
# Processing Record 12 of Set 10 | aldama
# Processing Record 13 of Set 10 | nicoya
# Processing Record 14 of Set 10 | juchitlan
# Processing Record 15 of Set 10 | calbuco
# Processing Record 16 of Set 10 | hibbing
# Processing Record 17 of Set 10 | bracebridge
# Processing Record 18 of Set 10 | cunday
# Processing Record 19 of Set 10 | nyagan
# Processing Record 20 of Set 10 | pochutla
# Processing Record 21 of Set 10 | paita
# Processing Record 22 of Set 10 | baykit
# Processing Record 23 of Set 10 | kununurra
# Processing Record 24 of Set 10 | kuito
# Processing Record 25 of Set 10 | haines junction
# Processing Record 26 of Set 10 | bonavista
# Processing Record 27 of Set 10 | sorong
# Processing Record 28 of Set 10 | porto seguro
# Processing Record 29 of Set 10 | tulum
# Processing Record 30 of Set 10 | panama city
# Processing Record 31 of Set 10 | krasnoselkup
# Processing Record 32 of Set 10 | atbasar
# Processing Record 33 of Set 10 | kailua
# Processing Record 34 of Set 10 | calamar
# Processing Record 35 of Set 10 | hami
# Processing Record 36 of Set 10 | dakar
# Processing Record 37 of Set 10 | acajutla
# Processing Record 38 of Set 10 | kudahuvadhoo
# Processing Record 39 of Set 10 | blackwater
# Processing Record 40 of Set 10 | derzhavinsk
# Processing Record 41 of Set 10 | yabelo
# Processing Record 42 of Set 10 | seymchan
# Processing Record 43 of Set 10 | mehamn
# Processing Record 44 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 10 | zeya
# Processing Record 46 of Set 10 | labuhan
# Processing Record 47 of Set 10 | namatanai
# Processing Record 48 of Set 10 | broome
# Processing Record 49 of Set 10 | le port
# Processing Record 50 of Set 10 | gorontalo
# Processing Record 1 of Set 11 | san matias
# Processing Record 2 of Set 11 | auki
# Processing Record 3 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 11 | belchertown
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | tondano
# Processing Record 7 of Set 11 | khandyga
# Processing Record 8 of Set 11 | los llanos de aridane
# Processing Record 9 of Set 11 | samfya
# Processing Record 10 of Set 11 | yerky
# Processing Record 11 of Set 11 | tazovskiy
# Processing Record 12 of Set 11 | tyulyachi
# Processing Record 13 of Set 11 | yarkovo
# Processing Record 14 of Set 11 | gotsu
# Processing Record 15 of Set 11 | galveston
# Processing Record 16 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 11 | farah
# Processing Record 18 of Set 11 | turochak
# Processing Record 19 of Set 11 | inhambane
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | udachnyy
# Processing Record 22 of Set 11 | atherton
# Processing Record 23 of Set 11 | sakakah
# Processing Record 24 of Set 11 | khasan
# Processing Record 25 of Set 11 | sokoni
# Processing Record 26 of Set 11 | rodrigues alves
# Processing Record 27 of Set 11 | altamira
# Processing Record 28 of Set 11 | bambanglipuro
# Processing Record 29 of Set 11 | anadyr
# Processing Record 30 of Set 11 | jiazi
# Processing Record 31 of Set 11 | abu zabad
# Processing Record 32 of Set 11 | ampanihy
# Processing Record 33 of Set 11 | sept-iles
# Processing Record 34 of Set 11 | vao
# Processing Record 35 of Set 11 | tual
# Processing Record 36 of Set 11 | killybegs
# Processing Record 37 of Set 11 | pamekasan
# Processing Record 38 of Set 11 | maragogi
# Processing Record 39 of Set 11 | grand-lahou
# Processing Record 40 of Set 11 | yalutorovsk
# Processing Record 41 of Set 11 | mweka
# Processing Record 42 of Set 11 | morros
# Processing Record 43 of Set 11 | sarangani
# Processing Record 44 of Set 11 | touros
# Processing Record 45 of Set 11 | ballina
# Processing Record 46 of Set 11 | sarmanovo
# Processing Record 47 of Set 11 | alofi
# Processing Record 48 of Set 11 | effingham
# Processing Record 49 of Set 11 | tire
# Processing Record 50 of Set 11 | acapulco
# Processing Record 1 of Set 12 | bintulu
# Processing Record 2 of Set 12 | marzuq
# Processing Record 3 of Set 12 | pena
# Processing Record 4 of Set 12 | belmonte
# Processing Record 5 of Set 12 | sarankhola
# Processing Record 6 of Set 12 | alice springs
# Processing Record 7 of Set 12 | xinqing
# Processing Record 8 of Set 12 | sao francisco de assis
# Processing Record 9 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 12 | shakawe
# Processing Record 11 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 12 | kondinskoye
# Processing Record 13 of Set 12 | kalmunai
# Processing Record 14 of Set 12 | la palma
# Processing Record 15 of Set 12 | southbridge
# Processing Record 16 of Set 12 | lebu
# Processing Record 17 of Set 12 | is
# City not found. Skipping...
# Processing Record 18 of Set 12 | taltal
# Processing Record 19 of Set 12 | hovd
# Processing Record 20 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 12 | biak
# Processing Record 22 of Set 12 | shelburne
# Processing Record 23 of Set 12 | meulaboh
# Processing Record 24 of Set 12 | jieshi
# Processing Record 25 of Set 12 | yumen
# Processing Record 26 of Set 12 | wenzhou
# Processing Record 27 of Set 12 | richards bay
# Processing Record 28 of Set 12 | paragominas
# Processing Record 29 of Set 12 | guapo
# Processing Record 30 of Set 12 | vila velha
# Processing Record 31 of Set 12 | zaysan
# Processing Record 32 of Set 12 | wakkanai
# Processing Record 33 of Set 12 | makokou
# Processing Record 34 of Set 12 | kupang
# Processing Record 35 of Set 12 | cervo
# Processing Record 36 of Set 12 | colorado springs
# Processing Record 37 of Set 12 | adelanto
# Processing Record 38 of Set 12 | mareeba
# Processing Record 39 of Set 12 | tilichiki
# Processing Record 40 of Set 12 | murray bridge
# Processing Record 41 of Set 12 | syracuse
# Processing Record 42 of Set 12 | borsad
# Processing Record 43 of Set 12 | carolina
# Processing Record 44 of Set 12 | roma
# Processing Record 45 of Set 12 | matamoros
# Processing Record 46 of Set 12 | talnakh
# Processing Record 47 of Set 12 | san jose
# Processing Record 48 of Set 12 | xam nua
# Processing Record 49 of Set 12 | manjakandriana
# Processing Record 50 of Set 12 | arsk
# Processing Record 1 of Set 13 | bathsheba
# Processing Record 2 of Set 13 | brazzaville
# Processing Record 3 of Set 13 | bushehr
# Processing Record 4 of Set 13 | port hedland
# Processing Record 5 of Set 13 | ust-maya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 559

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# Display sample data
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Adrar  20.5022  -10.0711     72.05        16         100
# 1            Avarua -21.2078 -159.7750     78.85        89          75
# 2          Umm Lajj  25.0213   37.2685     73.98        51           1
# 3  Puerto Leguizamo  -0.1934  -74.7819     94.01        34          66
# 4            Barrow  71.2906 -156.7887     -0.38        78         100
# 5              Kyra  49.5776  111.9753     -4.34        90           5
# 6           Rikitea -23.1203 -134.9692     76.64        73          35
# 7             Tiksi  71.6872  128.8694     -3.50        95         100
# 8            Likasi -10.9814   26.7333     61.65        98         100
# 9            Atuona  -9.8000 -139.0333     77.67        76          17
#
#    Wind Speed Country Current Description
# 0        8.97      MR     overcast clouds
# 1        5.75      CK          light rain
# 2       11.52      SA           clear sky
# 3        5.77      CO       broken clouds
# 4        9.22      US     overcast clouds
# 5        6.15      RU           clear sky
# 6        5.44      PF    scattered clouds
# 7       12.95      RU     overcast clouds
# 8        2.59      CD          light rain
# 9       18.01      PF          few clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Adrar      MR  20.5022  -10.0711     72.05        16
# 1            Avarua      CK -21.2078 -159.7750     78.85        89
# 2          Umm Lajj      SA  25.0213   37.2685     73.98        51
# 3  Puerto Leguizamo      CO  -0.1934  -74.7819     94.01        34
# 4            Barrow      US  71.2906 -156.7887     -0.38        78
# 5              Kyra      RU  49.5776  111.9753     -4.34        90
# 6           Rikitea      PF -23.1203 -134.9692     76.64        73
# 7             Tiksi      RU  71.6872  128.8694     -3.50        95
# 8            Likasi      CD -10.9814   26.7333     61.65        98
# 9            Atuona      PF  -9.8000 -139.0333     77.67        76
#
#    Cloudiness  Wind Speed Current Description
# 0         100        8.97     overcast clouds
# 1          75        5.75          light rain
# 2           1       11.52           clear sky
# 3          66        5.77       broken clouds
# 4         100        9.22     overcast clouds
# 5           5        6.15           clear sky
# 6          35        5.44    scattered clouds
# 7         100       12.95     overcast clouds
# 8         100        2.59          light rain
# 9          17       18.01          few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file)
